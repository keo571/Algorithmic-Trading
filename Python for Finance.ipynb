# %%
import pandas_datareader as pdr
import datetime
aapl = pdr.get_data_yahoo('AAPL',
                          start=datetime.datetime(2014,1,1),
                          end=datetime.datetime(2021,1,12))

# %%
aapl.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2014-01-02  19.893929  19.715000  19.845715  19.754642  234684800.0  17.624594
# 2014-01-03  19.775000  19.301071  19.745001  19.320715  392467600.0  17.237455
# 2014-01-06  19.528570  19.057142  19.194643  19.426071  412610800.0  17.331453
# 2014-01-07  19.498571  19.211430  19.440001  19.287144  317209200.0  17.207500
# 2014-01-08  19.484285  19.238930  19.243214  19.409286  258529600.0  17.316477

# %%
aapl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1770.000000  1770.000000  1770.000000  1770.000000  1.770000e+03
# mean     45.322639    44.384184    44.846980    44.873522  1.610041e+08
# std      25.758213    24.973121    25.381069    25.380685  8.785595e+07
# min      17.911785    17.626785    17.684999    17.849285  4.544800e+07
# 25%      27.948750    27.311250    27.605625    27.596875  1.023511e+08
# 50%      38.341249    37.417501    37.820000    37.863750  1.369370e+08
# 75%      51.587499    50.711874    51.071874    51.123125  1.958014e+08
# max     138.789993   134.339996   138.050003   136.690002  1.065523e+09
#
#          Adj Close
# count  1770.000000
# mean     43.392400
# std      25.976192
# min      15.924679
# 25%      25.644329
# 50%      36.416990
# 75%      50.248724
# max     136.690002

# %%
aapl.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
aapl.index
# Out:
# DatetimeIndex(['2014-01-02', '2014-01-03', '2014-01-06', '2014-01-07',
#                '2014-01-08', '2014-01-09', '2014-01-10', '2014-01-13',
#                '2014-01-14', '2014-01-15',
#                ...
#                '2020-12-29', '2020-12-30', '2020-12-31', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-11', '2021-01-12'],
#               dtype='datetime64[ns]', name='Date', length=1770, freq=None)

# %%
ts = aapl['Close'][-10:]

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
# Out:
# Timestamp('2014-01-02 00:00:00')

# %%
aapl.loc[pd.Timestamp('2014-01-01'):pd.Timestamp('2014-02-01')].head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2014-01-02  19.893929  19.715000  19.845715  19.754642  234684800.0  17.624594
# 2014-01-03  19.775000  19.301071  19.745001  19.320715  392467600.0  17.237455
# 2014-01-06  19.528570  19.057142  19.194643  19.426071  412610800.0  17.331453
# 2014-01-07  19.498571  19.211430  19.440001  19.287144  317209200.0  17.207500
# 2014-01-08  19.484285  19.238930  19.243214  19.409286  258529600.0  17.316477

# %%
aapl.loc['2020-01-02']
# Out:
# High         7.515000e+01
# Low          7.379750e+01
# Open         7.406000e+01
# Close        7.508750e+01
# Volume       1.354804e+08
# Adj Close    7.444460e+01
# Name: 2020-01-02 00:00:00, dtype: float64

# %%
aapl.iloc[22:30][['High','Low']]
# Out:
#                  High        Low
# Date
# 2014-02-04  18.195000  17.955713
# 2014-02-05  18.402857  18.080357
# 2014-02-06  18.339287  18.136070
# 2014-02-07  18.676071  18.477858
# 2014-02-10  18.999643  18.500000
# 2014-02-11  19.205357  18.910713
# 2014-02-12  19.270000  19.044287
# 2014-02-13  19.458929  19.078571

# %%
aapl.iloc[[22,30],[0,4]]
# Out:
#                  High       Volume
# Date
# 2014-02-04  18.195000  376681200.0
# 2014-02-14  19.499287  272924400.0

# %%
monthly_aapl = aapl.resample('M').mean()

# %%
monthly_aapl
# Out:
#                   High         Low        Open       Close        Volume  \
# Date
# 2014-01-31   19.387313   19.038061   19.217891   19.194490  4.174264e+08
# 2014-02-28   18.956203   18.647368   18.775752   18.806429  3.094930e+08
# 2014-03-31   19.159065   18.931105   19.056905   19.043367  2.381761e+08
# 2014-04-30   19.441037   19.152228   19.288639   19.324082  3.064315e+08
# 2014-05-31   21.656173   21.369031   21.475068   21.542704  2.731271e+08
# ...                ...         ...         ...         ...           ...
# 2020-09-30  118.036190  112.584762  116.079048  115.125237  1.850365e+08
# 2020-10-31  118.274546  114.911363  116.694090  116.413182  1.315917e+08
# 2020-11-30  118.198999  115.410500  116.748501  116.825999  1.061539e+08
# 2020-12-31  128.608182  125.727726  127.150455  127.290455  1.055832e+08
# 2021-01-31  131.502860  127.859998  129.801429  129.681428  1.147060e+08
#
#              Adj Close
# Date
# 2014-01-31   17.124840
# 2014-02-28   16.863767
# ...

# %%
aapl.asfreq('M', method='bfill')
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2014-01-31   17.911785   17.626785   17.684999   17.878571  464797200.0
# 2014-02-28   19.026787   18.647142   18.895714   18.794287  371968800.0
# 2014-03-31   19.314644   19.140356   19.258215   19.169287  168669200.0
# 2014-04-30   21.408215   21.064285   21.165714   21.074642  456640800.0
# 2014-05-31   22.672501   22.232143   22.641430   22.451786  369350800.0
# ...                ...         ...         ...         ...          ...
# 2020-08-31  131.000000  126.000000  127.580002  129.039993  225702700.0
# 2020-09-30  117.260002  113.620003  113.790001  115.809998  142675200.0
# 2020-10-31  110.680000  107.320000  109.110001  108.769997  122866900.0
# 2020-11-30  120.970001  116.809998  116.970001  119.050003  169410200.0
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   98990400.0
#
#              Adj Close
# Date
# 2014-01-31   15.950813
# 2014-02-28   16.868156
# ...

# %%
aapl['diff'] = aapl.Open - aapl.Close

# %%
aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2014-01-02   19.893929   19.715000   19.845715   19.754642  234684800.0
# 2014-01-03   19.775000   19.301071   19.745001   19.320715  392467600.0
# 2014-01-06   19.528570   19.057142   19.194643   19.426071  412610800.0
# 2014-01-07   19.498571   19.211430   19.440001   19.287144  317209200.0
# 2014-01-08   19.484285   19.238930   19.243214   19.409286  258529600.0
# ...                ...         ...         ...         ...          ...
# 2021-01-06  131.050003  126.379997  127.720001  126.599998  155088000.0
# 2021-01-07  131.630005  127.860001  128.360001  130.919998  109578200.0
# 2021-01-08  132.630005  130.229996  132.429993  132.050003  104965400.0
# 2021-01-11  130.169998  128.500000  129.190002  128.979996  100620900.0
# 2021-01-12  129.690002  126.860001  128.500000  128.800003   91722800.0
#
#              Adj Close      diff
# Date
# 2014-01-02   17.624594  0.091072
# ...

# %%
import matplotlib.pyplot as plt
aapl['Close'].plot(grid=True)
plt.show()

# %%
# Common Financial Analysis
## Returns
import numpy as np
daily_close = aapl[['Adj Close']]
daily_pct_change = daily_close.pct_change()
daily_pct_change.fillna(0, inplace=True)
daily_log_returns = np.log(daily_pct_change+1)
# Out:
#             Adj Close
# Date
# 2014-01-02   0.000000
# 2014-01-03  -0.022211
# 2014-01-06   0.005438
# 2014-01-07  -0.007178
# 2014-01-08   0.006313
# ...               ...
# 2021-01-06  -0.034241
# 2021-01-07   0.033554
# 2021-01-08   0.008594
# 2021-01-11  -0.023523
# 2021-01-12  -0.001396
#
# [1770 rows x 1 columns]

# %%
monthly = aapl.resample('BM').apply(lambda x: x[-1])
monthly.pct_change()
quarter = aapl.resample('4M').mean()
quarter.pct_change()
# Out:
#                 High       Low      Open     Close    Volume  Adj Close  \
# Date
# 2014-01-31       NaN       NaN       NaN       NaN       NaN        NaN
# 2014-05-31  0.022513  0.026698  0.023546  0.026359 -0.326512   0.033531
# 2014-09-30  0.228071  0.225256  0.227633  0.226019 -0.212340   0.234471
# 2015-01-31  0.134026  0.129040  0.132174  0.130855 -0.019486   0.137361
# 2015-05-31  0.158719  0.162504  0.160877  0.161185 -0.050668   0.168043
# 2015-09-30 -0.051924 -0.055424 -0.053692 -0.054188  0.071908  -0.049064
# 2016-01-31 -0.078187 -0.078441 -0.077890 -0.077706 -0.115089  -0.072591
# 2016-05-31 -0.093560 -0.090332 -0.093590 -0.091564 -0.188959  -0.084460
# 2016-09-30  0.028003  0.032185  0.029462  0.029523 -0.101439   0.037531
# 2017-01-31  0.108762  0.109379  0.109384  0.109995 -0.127241   0.117092
# 2017-05-31  0.240110  0.243391  0.241905  0.241528 -0.161404   0.249267
# 2017-09-30  0.077632  0.072702  0.077253  0.074566  0.104515   0.080355
# ...

# %%
daily_pct_change.hist(bins=50)
plt.show()

# %%
daily_pct_change.describe()
# Out:
#          Adj Close
# count  1770.000000
# mean      0.001287
# std       0.018047
# min      -0.128647
# 25%      -0.006337
# 50%       0.000947
# 75%       0.010018
# max       0.119808

# %%
cum_daily_return = (1+daily_pct_change).cumprod()
cum_daily_return
# Out:
#             Adj Close
# Date
# 2014-01-02   1.000000
# 2014-01-03   0.978034
# 2014-01-06   0.983368
# 2014-01-07   0.976335
# 2014-01-08   0.982518
# ...               ...
# 2021-01-06   7.183144
# 2021-01-07   7.428256
# 2021-01-08   7.492371
# 2021-01-11   7.318183
# 2021-01-12   7.307970
#
# [1770 rows x 1 columns]

# %%
cum_daily_return.plot(figsize=(12,8))
plt.show()

# %%
cum_monthly_return = cum_daily_return.resample('M').mean()
cum_monthly_return
# Out:
#             Adj Close
# Date
# 2014-01-31   0.971645
# 2014-02-28   0.956832
# 2014-03-31   0.969765
# 2014-04-30   0.984060
# 2014-05-31   1.101731
# ...               ...
# 2020-09-30   6.520829
# 2020-10-31   6.593780
# 2020-11-30   6.626364
# 2020-12-31   7.222320
# 2021-01-31   7.357981
#
# [85 rows x 1 columns]

# %%
def get(tickers, startdate, enddate):
    def data(ticker):
        return (pdr.get_data_yahoo(ticker, start=startdate, end=enddate))
    datas = map (data, tickers)
    return(pd.concat(datas, keys=tickers, names=['Ticker', 'Date']))

tickers = ['AAPL', 'F', 'IBM', 'TSLA']
all_data = get(tickers, datetime.datetime(2018, 1, 1), datetime.datetime(2021, 1, 12))

# %%
all_data
# Out:
#                          High         Low        Open       Close  \
# Ticker Date
# AAPL   2018-01-02   43.075001   42.314999   42.540001   43.064999
#        2018-01-03   43.637501   42.990002   43.132500   43.057499
#        2018-01-04   43.367500   43.020000   43.134998   43.257500
#        2018-01-05   43.842499   43.262501   43.360001   43.750000
#        2018-01-08   43.902500   43.482498   43.587502   43.587502
# ...                       ...         ...         ...         ...
# TSLA   2021-01-06  774.000000  749.099976  758.489990  755.979980
#        2021-01-07  816.989990  775.200012  777.630005  816.039978
#        2021-01-08  884.489990  838.390015  856.000000  880.020020
#        2021-01-11  854.429993  803.619995  849.400024  811.190002
#        2021-01-12  868.000000  827.340027  831.000000  849.440002
#
#                         Volume   Adj Close
# Ticker Date
# AAPL   2018-01-02  102223600.0   41.442081
#        2018-01-03  118071600.0   41.434864
# ...

# %%
daily_close_px = all_data[['Adj Close']].reset_index().pivot('Date','Ticker','Adj Close')
daily_pct_change = daily_close_px.pct_change()
daily_pct_change.hist(bins=50, sharex=True, figsize=(12,8))
plt.show()

# %%
pd.plotting.scatter_matrix(daily_pct_change, diagonal='kde', alpha=0.1, figsize=(12,12))
plt.show()

# %%
# Moving Windows
